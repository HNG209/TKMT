# %% [markdown]
# # Lab 02 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
import numpy as np
import matplotlib.pyplot as plt

arr = np.random.randint(1000 ,size = 100)
print(arr)
print(arr[0:10])
print(arr[-5:])
print(arr[np.where((arr % 5 == 0) & (arr > 100))])
# Out:
# [941 380  87  10 794 373   8 290 182 744 289 529 755 833 325 403  54 389
#  924 329 435 340 842 977 172 958 710 583 793 489 598 448 667 626 817 371
#  599 305 895 475  89 471 751 517 839 458 759  95 598 692 727  15 324 188
#  535 814 691 938 132 412 577 222 126 696 501 258 398 417 248 191 884 473
#  448 592 583 621 938 357 331 227  86  75 169 825  24  82 376 528 724 322
#  137 878 391 329 245 539 843 536 295 721]
# [941 380  87  10 794 373   8 290 182 744]
# [539 843 536 295 721]
# [380 290 755 325 435 340 710 305 895 475 535 825 245 295]

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
print(np.count_nonzero(arr < 100))
# Out:
# 11

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print(arr.sum())
print(arr.mean())
print(np.median(arr))
print(np.quantile(arr, [0.25, 0.5, 0.75]))
print(np.percentile(arr, 20))
# Out:
# 47997
# 479.97
# 464.5
# [289.75 464.5  712.75]
# 226.0

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
print(np.random.choice(arr, size=10, replace=False))
print(np.random.choice(arr, size=10, replace=False))
print(np.random.choice(arr, size=10, replace=False))
print(np.random.choice(arr, size=10, replace=False))
print(np.random.choice(arr, size=10, replace=False))
# Out:
# [227 977 814 710 290 696 398 403 598 357]
# [878  86 475 182 667 691 398 583 621 391]
# [839 227  15 941 755 583 448 376 825 528]
# [535  82 357 501 448 305 938 169 389 371]
# [371 583  15 471 305 958 331 938 884 376]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
d = {}
for i in range(0, len(arr)):
    if arr[i] in d:
        d[arr[i]] = d[arr[i]] + 1
    else:
        d[arr[i]] = 1

m = np.array(list(d.values())).max()

for i in d:
    if d[i] == m:
        print(i)
# Out:
# 329
# 583
# 598
# 448
# 938

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị giống hình sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# This cell contains output. Don't remove!

# %%
plt.plot([1, 2, 3], [2 ,4, 1])

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# This cell contains output. Don't remove!

# %%
plt.plot([10,20,30], [40, 10, 30])
plt.plot([10,20,30], [20, 40, 10])

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# This cell contains output. Don't remove!

# %%
plt.plot([1, 4, 5, 6, 7], [2, 6, 3, 6, 3], marker='.', mfc='red', markersize = 15)

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
# This cell contains output. Don't remove!

# %%
x = np.linspace(0, 6.5, 1000)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x), '--')
plt.grid(True)

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
# This cell contains output. Don't remove!

# %%
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), label='sin(x)')
plt.legend(loc='upper right')

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), 'r', label='cos(x)')
plt.legend(loc='lower left')

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# This cell contains output. Don't remove!

# %%
plt.bar(['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'], [21, 17, 9, 8, 7, 6])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# This cell contains output. Don't remove!

# %%
mylabels = ['PHP', 'Python', 'Java', 'C++', 'C#', 'JavaScript']
values = np.array([12.39, 24.79, 31.27, 9.44, 10.85, 11.27])
myexplode = [0, 0, 0.2, 0, 0, 0]

plt.pie(values, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# This cell contains output. Don't remove!

# %%
x = np.random.normal(size=10000)

plt.hist(x
        , bins=100          # Chia thành 100 cột
        , density=True      # Giá trị tung độ là mật độ
        , stacked=True
        , color='green'     
        , edgecolor='white' # màu cạnh
        )

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')

plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# This cell contains output. Don't remove!

# %%
data = np.random.normal(size=10000)

plt.boxplot(x=data)
plt.title("Boxplot")

plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
# This cell contains output. Don't remove!

# %%
plt.subplot(2, 1, 1)
plt.hist(x
        , bins=100          # Chia thành 100 cột
        , density=True      # Giá trị tung độ là mật độ
        , stacked=True
        , color='purple'     
        , edgecolor='white' # màu cạnh
        )

plt.xlabel('Value')
plt.ylabel('Mật độ')
plt.title('Histogram')

plt.subplot(2, 1, 2)

plt.boxplot(x=data, vert = False)
plt.title("Boxplot")

plt.show()

# %% [markdown]
# ---
